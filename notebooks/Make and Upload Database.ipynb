# %%
# %cd ../..
# Out:
# /home/antoine/Gdrive/Autoencoders

# %%
import os

from mmk.data.factory import make_root_db
from mmk.data.api import Database
from mmk.utils import upload_database
# Out:
# mmk initialized with device: cuda

# %%
make_root_db("a_cappella.h5", "nessun_dorma/data/a_cappella")
# Out:
# /home/antoine/anaconda3/lib/python3.7/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/antoine/anaconda3/lib/python3.7/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/antoine/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py:2449: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block0_values] [items->MultiIndex([('directory',      ''),
#             (     'name',      ''),
#             (      'fft', 'dtype'),
#             (      'fft', 'shape'),
#             (      'fft',  'size')],
#            )]
#
#   encoding=encoding,
# /home/antoine/anaconda3/lib/python3.7/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/antoine/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py:2449: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block0_values] [items->MultiIndex([('directory',      ''),
#             (     'name',      ''),
#             (      'fft', 'dtype'),
#             (      'fft', 'shape'),
#             (      'fft',  'size')],
#            )]
#
#   encoding=encoding,
# /home/antoine/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py:2449: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block0_values] [items->MultiIndex([('directory',      ''),
#             (     'name',      ''),
#             (      'fft', 'dtype'),
#             (      'fft', 'shape'),
#             (      'fft',  'size')],
#            )]
#
#   encoding=encoding,
# /home/antoine/anaconda3/lib/python3.7/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/antoine/anaconda3/lib/python3.7/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/antoine/anaconda3/lib/python3.7/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/antoine/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py:2449: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block0_values] [items->MultiIndex([('directory',      ''),
#             (     'name',      ''),
#             (      'fft', 'dtype'),
#             (      'fft', 'shape'),
#             (      'fft',  'size')],
#            )]
#
#   encoding=encoding,
# /home/antoine/anaconda3/lib/python3.7/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/antoine/anaconda3/lib/python3.7/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/antoine/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py:2449: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block0_values] [items->MultiIndex([('directory',      ''),
#             (     'name',      ''),
#             (      'fft', 'dtype'),
#             (      'fft', 'shape'),
#             (      'fft',  'size')],
#            )]
#
#   encoding=encoding,
# /home/antoine/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py:2449: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block0_values] [items->MultiIndex([('directory',      ''),
#             (     'name',      ''),
#             (      'fft', 'dtype'),
#             (      'fft', 'shape'),
#             (      'fft',  'size')],
#            )]
#
#   encoding=encoding,
# /home/antoine/anaconda3/lib/python3.7/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/antoine/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py:2449: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block0_values] [items->MultiIndex([('directory',      ''),
#             (     'name',      ''),
#             (      'fft', 'dtype'),
#             (      'fft', 'shape'),
#             (      'fft',  'size')],
#            )]
#
#   encoding=encoding,
# /home/antoine/anaconda3/lib/python3.7/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/antoine/anaconda3/lib/python3.7/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/antoine/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py:2449: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block0_values] [items->MultiIndex([('directory',      ''),
#             (     'name',      ''),
#             (      'fft', 'dtype'),
#             (      'fft', 'shape'),
#             (      'fft',  'size')],
#            )]
#
#   encoding=encoding,
# /home/antoine/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py:2449: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block0_values] [items->MultiIndex([('directory',      ''),
#             (     'name',      ''),
#             (      'fft', 'dtype'),
#             (      'fft', 'shape'),
#             (      'fft',  'size')],
#            )]
#
#   encoding=encoding,
# /home/antoine/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py:2449: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block0_values] [items->MultiIndex([('directory',      ''),
#             (     'name',      ''),
#             (      'fft', 'dtype'),
#             (      'fft', 'shape'),
#             (      'fft',  'size')],
#            )]
#
#   encoding=encoding,
# /home/antoine/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py:2449: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block0_values] [items->MultiIndex([('directory',      ''),
#             (     'name',      ''),
#             (      'fft', 'dtype'),
#             (      'fft', 'shape'),
#             (      'fft',  'size')],
#            )]
#
#   encoding=encoding,
# /home/antoine/anaconda3/lib/python3.7/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/antoine/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py:2449: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block0_values] [items->MultiIndex([('directory',      ''),
#             (     'name',      ''),
#             (      'fft', 'dtype'),
#             (      'fft', 'shape'),
#             (      'fft',  'size')],
#            )]
#
#   encoding=encoding,
# /home/antoine/anaconda3/lib/python3.7/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/antoine/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py:2449: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block0_values] [items->MultiIndex([('directory',      ''),
#             (     'name',      ''),
#             (      'fft', 'dtype'),
#             (      'fft', 'shape'),
#             (      'fft',  'size')],
#            )]
#
#   encoding=encoding,
# /home/antoine/anaconda3/lib/python3.7/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/antoine/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py:2449: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block0_values] [items->MultiIndex([('directory',      ''),
#             (     'name',      ''),
#             (      'fft', 'dtype'),
#             (      'fft', 'shape'),
#             (      'fft',  'size')],
#            )]
#
#   encoding=encoding,
# /home/antoine/anaconda3/lib/python3.7/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/antoine/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py:2449: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block0_values] [items->MultiIndex([('directory',      ''),
#             (     'name',      ''),
#             (      'fft', 'dtype'),
#             (      'fft', 'shape'),
#             (      'fft',  'size')],
#            )]
#
#   encoding=encoding,
# /home/antoine/anaconda3/lib/python3.7/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/antoine/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py:2449: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block0_values] [items->MultiIndex([('directory',      ''),
#             (     'name',      ''),
#             (      'fft', 'dtype'),
#             (      'fft', 'shape'),
#             (      'fft',  'size')],
#            )]
#
#   encoding=encoding,
# /home/antoine/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py:2449: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block0_values] [items->MultiIndex([('directory',      ''),
#             (     'name',      ''),
#             (      'fft', 'dtype'),
#             (      'fft', 'shape'),
#             (      'fft',  'size')],
#            )]
#
#   encoding=encoding,

# %%
db = Database("a_cappella.h5")
db.metadata
# Out:
#         start     stop  duration  \
# 0           0      528       528
# 1         528     1096       568
# 2        1096     1384       288
# 3        1384     1780       396
# 4        1780     2130       350
# ...       ...      ...       ...
# 2939  1101435  1101899       464
# 2940  1101899  1102228       329
# 2941  1102228  1102693       465
# 2942  1102693  1103043       350
# 2943  1103043  1103429       386
#
#                                                    name
# 0     nessun_dorma/data/a_cappella/slow_piano/f7_sca...
# 1     nessun_dorma/data/a_cappella/slow_piano/f8_sca...
# 2     nessun_dorma/data/a_cappella/slow_piano/f9_arp...
# 3     nessun_dorma/data/a_cappella/slow_piano/m2_arp...
# 4     nessun_dorma/data/a_cappella/slow_piano/f7_arp...
# ...                                                 ...
# 2939  nessun_dorma/data/a_cappella/breathy/m9_scales...
# 2940  nessun_dorma/data/a_cappella/breathy/f7_arpegg...
# 2941  nessun_dorma/data/a_cappella/breathy/f8_scales...
# 2942  nessun_dorma/data/a_cappella/breathy/m7_arpegg...
# 2943  nessun_dorma/data/a_cappella/breathy/m7_arpegg...
#
# [2944 rows x 4 columns]

# %%
api_token = os.environ.get("KTONAL_NEPTUNE_API_TOKEN")

upload_database(db, api_token, "k-tonal/data", "Arie-Nessun-Dorma")
# Out:
# https://ui.neptune.ai/k-tonal/data/e/DAT-4

# %%
import h5py
import pandas as pd 
import os

def format_filename(d, fn=None):
    fn = fn.split(".")[0]
    parts = fn.split("_")
    singer = parts[0]
    vowel = parts[-1]
    technique = d.split("/")[-1]
    motif = "_".join([x for x in parts[1:-1] if x not in technique])
    return singer, motif, technique, vowel

labels = pd.DataFrame([format_filename(*os.path.split(t.name)) 
                      for t in db.metadata[["name"]].itertuples()],
                     columns=["singer", "motif", "technique", 'vowel'])
db.save_dataframe("labels", labels)

db = Database("a_cappella.h5")
db.labels
# Out:
# <class 'numpy.ndarray'>
#      singer        motif   technique vowel
# 0        f7     scales_f  slow_piano     i
# 1        f8     scales_c  slow_piano     u
# 2        f9  arpeggios_f  slow_piano     e
# 3        m2  arpeggios_c  slow_piano     i
# 4        f7  arpeggios_f  slow_piano     o
# ...     ...          ...         ...   ...
# 2939     m9       scales     breathy     o
# 2940     f7    arpeggios     breathy     i
# 2941     f8       scales     breathy     o
# 2942     m7    arpeggios     breathy     i
# 2943     m7    arpeggios     breathy     o
#
# [2944 rows x 4 columns]
